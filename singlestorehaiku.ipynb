# %% [markdown]
# # The "Vector Database Cluster" includes nodes for indexing, data storage, and machine learning models, showcasing a more detailed infrastructure.
# #
# The "AI Processing System" features a neural network with distinct layers (input, hidden, and output) to represent the flow and processing of information within the AI.#
# Arrows indicate data flow and interactions between the two main components, emphasizing the dynamic exchange and processing integral to AI and database systems.
#                 --------------------+

# %%
                  +----------------------------------------+
                  |          Vector Database Cluster       |
                  | +------------------------------------+ |
                  | |            Search Nodes            | |
                  | | +--------+    +--------+    +-----+| |
                  | | | Index  |<-->| Vector |<-->| AI  || |
   +---------------> | | Server |    | Store  |    | ML  || |
   |              | | +--------+    +--------+    +-----+| |
   |              | +------------------------------------+ |
   |              +----------------------------------------+
   |
  /|\             +----------------------------------------+
   |              |          AI Processing System          |
   |              | +------------------------------------+ |
   |              | |         Deep Neural Network         | |
   +--------------| | +-------+    +--------+    +------+| |
                  | | | Input |<-->| Hidden |<-->|Output|| |
                  | | | Layer |    | Layers |    |Layer || |
                  | | +-------+    +--------+    +------+| |
                  | +------------------------------------+ |
                  +----------------------------------------+
